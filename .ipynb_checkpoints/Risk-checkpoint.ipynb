# %%
class Territory():
    def __init__(self, c_t_id, name, continent, Map): # adjacencies
        self.id = Map.num_territories
        Map.num_territories = Map.num_territories+1
        self.c_t_id = c_t_id
        self.name = name
        self.continent = continent #continent id
        self.player_id = -1
        self.num_troops = 0
        self.adjacencies = [] #list of adjacent territories id
    
    def set_territory_adjacencies(self, adjacencies):
        for i in adjacencies:
            self.adjacencies.append(i)
    
    def set_territory_player(self, player_id):
        self.player_id = player_id
    
    def territory_num_troops(self, num):
        self.num_troops = num
    
    def print_details(self):
        print("Territory ID: ", self.id)
        print("Territory Name: ", self.name)
        print("Territory Continent: ", self.continent)
        print("Territory Player ID: ", self.player_id)
        print("Territory Num of Troops: ", self.num_troops)
        if self.adjacencies:
            print("Territory Adjacencies: ", self.adjacencies)
        
    
class Continent():
    def __init__(self, c_id, name, territories, bonus, Map):
        self.id = c_id
        self.name = name
        self.num_territories = len(territories)
        self.territories = [] #list of territories

        for i in range(self.num_territories):
            c_t_id = c_id+((i+1)/100)
            territory = Territory(c_t_id, territories[i], c_id, Map)
            self.territories.append(territory)
            Map.territories.append(territory)

        self.all_owned = -1 # player id will be stored if all owned by the same player
        self.bonus = bonus
    
    #@property
    def check_owned(self):
        self.all_owned = self.territories[0].player_id
        for i in len(self.territories)-1:
            if self.territories[i].player_id != self.territories[i+1].player_id:
                self.all_owned = -1
        
        #either returning -1 or the player id of player who owns all territories of this continent
        return self.all_owned 
            #Player[self.all_owned].continents_owned.append(self.id)
            
    def print_details(self):
        print("Continent ID: ", self.id)
        print("Continent Name: ", self.name)
        print("Continent Territories: ", self.territories)
        print("Continent All Owned Player ID: ", self.all_owned)
        print("Continent Bonus: ", self.bonus)

class Player():
    def __init__(self, p_id):
        self.id = p_id
        self.territories_owned = [] #list of owned territories ids
        self.is_alive = True
        self.num_troops = 0
        self.continents_owned = [] #list of owned continents ids
        self.num_turns = 0
        
    @property
    def give_bonus(self):
        for i in len(self.continents_owned):
            bonus = Continent[self.continents_owned[i]].bonus
        if bonus >= 3:
            self.num_troops = self.num_troops + 3
        else:
            self.num_troops = self.num_troops + bonus
            
    @property
    def check_if_alive(self):
        if len(territories_owned) <= 0 and num_turns > 0:
            self.is_alive = False
        else:
            self.is_alive = True

    def print_details(self):
        print("Player ID: ", self.id)
        print("Player Territories Owned: ", self.territories_owned)
        if self.is_alive == False:
            print("Player is Dead")
        elif self.is_alive == True:
            print("Player is Alive")
        print("Player Number of Troops: ", self.num_troops)
        if len(continents_owned) > 0:
            print("Player Continents Owned: ", self.continents_owned)
        print("Player Number of Turns Played: ", self.num_turns)

class Map():
    def __init__(self):
        self.territories = []
        self.continents = []
        num_territories = 0
        
        north_america = ['Alaska','Northwest Territory','Alberta','Ontario','Quebec','Western United States','Eastern United States','Central America','Greenland']
        south_america = ['Venezuela','Peru','Argentina','Brazil']
        europe = ['Iceland','Great Britain','Western Europe','Southern Europe','Northern Europe','Scandinavia','Ukraine']
        asia = ['Middle East','Afghanistan','Ural','Siberia','Yakutsk','Kamchatka','Irkutsk','Mongolia','Japan','China','Siam','India']
        africa = ['North Africa','Egypt','East Africa','Congo','South Africa','Madagascar']
        australia = ['Philippines','Indonesia','Papua New Guinea','Eastern Australia','Western Australia']
        
        
        self.continents.append(Continent(0,'North America', north_america, 5))
        self.continents.append(Continent(1,'South America', south_america, 2))
        self.continents.append(Continent(2,'Europe', europe, 5))
        self.continents.append(Continent(3,'Asia', asia, 7))
        self.continents.append(Continent(4,'Africa', africa, 3))
        self.continents.append(Continent(5,'Australia', australia, 2))
        
        #North America
        #Alaska
        self.continents[0].pays[0].set_territory_adjacencies([1,2,25])
        #Northwest Territory
        self.continents[0].pays[1].set_territory_adjacencies([0,2,3,8])
        #Alberta
        self.continents[0].pays[2].set_territory_adjacencies([0,1,3,5])
        #Ontario
        self.continents[0].pays[3].set_territory_adjacencies([1,2,4,5,6,8])
        #Quebec
        self.continents[0].pays[4].set_territory_adjacencies([3,6,8])
        #Western United States
        self.continents[0].pays[5].set_territory_adjacencies([2,3,6,7])
        #Eastern United States
        self.continents[0].pays[6].set_territory_adjacencies([3,4,5,7])
        #Central America
        self.continents[0].pays[7].set_territory_adjacencies([5,6,9])
        #Greenland
        self.continents[0].pays[8].set_territory_adjacencies([1,3,4,13])
        
        #South America
        #Venezuela
        self.continents[1].pays[0].set_territory_adjacencies([7,10,12])
        #Peru
        self.continents[1].pays[1].set_territory_adjacencies([9,11,12])
        #Argentina
        self.continents[1].pays[2].set_territory_adjacencies([10,12])
        #Brazil
        self.continents[1].pays[3].set_territory_adjacencies([9,10,11,32])
        
        #Europe
        #Iceland
        self.continents[2].pays[0].set_territory_adjacencies([8,14,18])
        #Great Britain
        self.continents[2].pays[1].set_territory_adjacencies([13,15,17,18])
        #Western Europe
        self.continents[2].pays[2].set_territory_adjacencies([14,16,17,32])
        #Southern Europe
        self.continents[2].pays[3].set_territory_adjacencies([15,17,19,20,32,33])
        #Northern Europe
        self.continents[2].pays[4].set_territory_adjacencies([14,15,16,18,19])
        #Scandinavia
        self.continents[2].pays[5].set_territory_adjacencies([13,14,17,19])
        #Ukraine
        self.continents[2].pays[6].set_territory_adjacencies([16,17,18,20,21,22])
        
        #Asia
        #Middle East
        self.continents[3].pays[0].set_territory_adjacencies([16,19,21,31,33,34])
        #Afghanistan
        self.continents[3].pays[1].set_territory_adjacencies([19,20,22,29,31])
        #Ural
        self.continents[3].pays[2].set_territory_adjacencies([19,21,23,29])
        #Siberia
        self.continents[3].pays[3].set_territory_adjacencies([22,24,26,27,29])
        #Yakutsk
        self.continents[3].pays[4].set_territory_adjacencies([23,25,26])
        #Kamchatka
        self.continents[3].pays[5].set_territory_adjacencies([0,24,26,27,28])
        #Irkutsk
        self.continents[3].pays[6].set_territory_adjacencies([23,24,25,27])
        #Mongolia
        self.continents[3].pays[7].set_territory_adjacencies([23,25,26,28,29])
        #Japan
        self.continents[3].pays[8].set_territory_adjacencies([25,27])
        #China
        self.continents[3].pays[9].set_territory_adjacencies([21,22,23,27,30,31,38])
        #Siam
        self.continents[3].pays[10].set_territory_adjacencies([29,31,39])
        #India
        self.continents[3].pays[11].set_territory_adjacencies([20,21,29,30])
                
        #Africa
        #North Africa
        self.continents[4].pays[0].set_territory_adjacencies([12,15,16,33,34,35])
        #Egypt
        self.continents[4].pays[1].set_territory_adjacencies([16,20,32,34])
        #East Africa
        self.continents[4].pays[2].set_territory_adjacencies([20,32,33,35,36,37])
        #Congo
        self.continents[4].pays[3].set_territory_adjacencies([32,34,36])
        #South Africa
        self.continents[4].pays[4].set_territory_adjacencies([34,35,37])
        #Madagascar
        self.continents[4].pays[5].set_territory_adjacencies([34,36])
                        
        #Australia
        #Philippines
        self.continents[4].pays[0].set_territory_adjacencies([29,39])
        #Indonesia
        self.continents[4].pays[1].set_territory_adjacencies([30,38,40,42])
        #Papua New Guinea
        self.continents[4].pays[2].set_territory_adjacencies([39,41,42])
        #Eastern Australia
        self.continents[4].pays[3].set_territory_adjacencies([40,42])
        #Western Australia
        self.continents[4].pays[4].set_territory_adjacencies([39,40,41])
        
class Risk():
    def __init__(self, num_of_players):
        if num_of_players > 6:
            print("Maximum number of players is 6!")
            return -1
        
        map = Map()

# %%
adjacencies = ["Malta", "Italy", "Morocco"]
len(adjacencies)
# Out:
# 3

# %%
c = 3
len = 12
for i in range(len):
    #print("I: ", i)
    d = c+((i+1)/100)
    print(d)

# %%
12/100

# %%
territories = ["Malta", "Italy", "Morocco"]
num_territories = len(territories)
print(num_territories)
c = 3
for i in range(num_territories):
    print("I:", i)
    print("Territory: ", territories[i])
    d = c+((i+1)/100)
    print(d)
    #territory = Territory(i, c_id)
# Out:
# 3
# I: 0
# Territory:  Malta
# 3.01
# I: 1
# Territory:  Italy
# 3.02
# I: 2
# Territory:  Morocco
# 3.03

# %%
territories = []
if territories:
    print("hi")
# Out:
# hi
